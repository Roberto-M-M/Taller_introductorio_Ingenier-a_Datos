# %% [raw]
# Nombre: Roberto Muñoz Millar         Carrera: Ingeniería Civil Inductrial          Ramo:Ingeniería de Datos
#
# Dataset de spotify-music: https://www.kaggle.com/datasets/arnavvvvv/spotify-music
#
# Contexto
# El conjunto de datos contiene una lista completa de las canciones más famosas y las canciones más reproducidas en Spotify.
#
# Proporciona información sobre cada canción.
#
# -Atributos
# -Popularidad
# -Presencia en diversas plataformas de música.
# -El conjunto de datos incluye información como el nombre de la pista.
#
# nombre del artista
# -Fecha de lanzamiento
# -Listas de reproducción y gráficos de Spotify
# -Estadísticas de transmisión
# -Presencia de Apple Music
# -Presencia de Deezer
# -Gráficos de Shazam
# -Varias funciones de audio

# %%
import pandas as pd

# %%
#Codigo para la lectura de archivo Kaggle: https://www.kaggle.com/datasets/arnavvvvv/spotify-music

url = "https://raw.githubusercontent.com/Roberto-M-M/Taller_introductorio_Ingenier-a_Datos/main/Popular_Spotify_Songs.csv"
datos_csv = pd.read_csv(url, encoding='latin1')
datos_csv
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
#1. Algo de exploración de los datos
datos_csv.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [raw]
# Vemos que el streams es un object siendo que es un numero.

# %%
#Se realizara una busque del valor diferente. 

valores_no_enteros = datos_csv[~datos_csv['streams'].astype(str).str.isdigit()]
valores_no_enteros
# Out:
#                               track_name     artist(s)_name  artist_count  \
# 574  Love Grows (Where My Rosemary Goes)  Edison Lighthouse             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 574           1970               1             1                  2877
#
#      in_spotify_charts                                            streams  \
# 574                  0  BPM110KeyAModeMajorDanceability53Valence75Ener...
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 574                  16  ...  110   A  Major             53         75
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 574       69              7                   0          17              3
#
# [1 rows x 24 columns]

# %% [raw]
# por lo tanto, tenemos que eliminar este valor para que todos los streams son numeros

# %%
datos_csv_url_clean = datos_csv.drop(valores_no_enteros.index)
# Verificar el DataFrame después de eliminar las filas
datos_csv_url_clean
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
datos_csv_url_clean.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [raw]
# Cambiamos de objeto a int64

# %%
datos_csv_url_clean['streams'] = datos_csv_url_clean['streams'].astype('int64')
datos_csv_url_clean.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                  int64
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [markdown]
# 4) Realice una breve exploración de los datos y saque las primeras conclusiones

# %% [raw]
# Se ve que varios de los datos son nueros enteros y no float, esto sera muy adecuado para trabajar en los datos.
# Cabe destacar que varios de estas columnas tendran que ser eliminadas por no aportar informacion.

# %%
datos_csv_url = datos_csv_url_clean
datos_csv_url.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    952.000000     952.000000      952.000000    952.000000
# mean       1.556723    2018.288866        6.038866     13.944328
# std        0.893331      11.011397        3.564571      9.197223
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  \
# count            952.000000         952.000000  9.520000e+02
# mean            5202.565126          12.022059  5.141374e+08
# std             7901.400683          19.582405  5.668569e+08
# min               31.000000           0.000000  2.762000e+03
# 25%              874.500000           0.000000  1.416362e+08
# ...

# %% [markdown]
# 5. Analice los datos categóricos encontrados para dos grupos de características diferentes. Escoja con libertad las características que desee, pero analice cuáles pueden ser agrupadas de mejor manera.

# %%
#para analizar los datos categóricos podemos utilizar la función groupby:
datos_csv_url.groupby(by =['track_name','streams']).size()
# Out:
# track_name                    streams
# 'Till I Collapse              1695712020    1
# (It Goes Like) Nanana - Edit  57876440      1
# 10 Things I Hate About You    185550869     1
# 10:35                         325592432     1
# 2 Be Loved (Am I Ready)       247689123     1
#                                            ..
# you broke me first            1180094974    1
# ýýý98 Braves                  56533272      1
# ýýýabcdefu                    1007612429    1
# ýýýýýýýýýýýý                  143573775     1
# ýýýýýýýýýýýýýýýýýýýýý         403097450     1
# Length: 951, dtype: int64

# %%
datos_csv_url.groupby(by=['track_name', 'artist(s)_name']).size()
# Out:
# track_name                    artist(s)_name
# 'Till I Collapse              Eminem, Nate Dogg      1
# (It Goes Like) Nanana - Edit  Peggy Gou              1
# 10 Things I Hate About You    Leah Kate              1
# 10:35                         Tiï¿½ï¿½sto, Tate M    1
# 2 Be Loved (Am I Ready)       Lizzo                  1
#                                                     ..
# you broke me first            Tate McRae             1
# ýýý98 Braves                  Morgan Wallen          1
# ýýýabcdefu                    Gayle                  1
# ýýýýýýýýýýýý                  YOASOBI                1
# ýýýýýýýýýýýýýýýýýýýýý         Fujii Kaze             1
# Length: 948, dtype: int64

# %% [markdown]
# 6.Verifique que haya datos faltantes en su dataset, si los hay, elimínelos para que no generen problemas posteriore

# %%
datos_csv_url.isna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [raw]
# Por lo que se ve no tiene ningun dato faltante dentro de este dataset.

# %% [markdown]
# 7.Insepeccione su dataset y verifique si hay datos duplicados. En caso de haberlos, elimine aquellos datos repetidos. Una vez eliminados, verifique que los datos repetidos hayan sido eliminados

# %%
datos_csv_url.nunique()
# Out:
# track_name              942
# artist(s)_name          644
# artist_count              8
# released_year            50
# released_month           12
# released_day             31
# in_spotify_playlists    878
# in_spotify_charts        82
# streams                 948
# in_apple_playlists      234
# in_apple_charts         172
# in_deezer_playlists     348
# in_deezer_charts         34
# in_shazam_charts        198
# bpm                     124
# key                      11
# mode                      2
# danceability_%           72
# valence_%                94
# energy_%                 80
# acousticness_%           98
# instrumentalness_%       39
# liveness_%               68
# speechiness_%            48
# dtype: int64

# %%
#Procedemos a inspeccionar primero cuáles podrían ser esos datos repetidos.
datos_csv_url_clean[datos_csv_url.duplicated(subset = ['track_name','streams'],keep=False)].sort_values('streams')
# Out:
#           track_name artist(s)_name  artist_count  released_year  \
# 372  About Damn Time          Lizzo             1           2022
# 764  About Damn Time          Lizzo             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 372               7            15                  2332                  2
# 764               4            14                  9021                  0
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 372  723894473                   0  ...  109  A#  Minor             84
# 764  723894473                 242  ...  109  A#  Minor             84
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 372         72       74             10                   0          34
# 764         72       74             10                   0          34
#
#      speechiness_%
# 372              7
# 764              7
#
# [2 rows x 24 columns]

# %%
datos_csv_url_clean[datos_csv_url.duplicated(subset = ['track_name','artist(s)_name'],keep=False)].sort_values('artist(s)_name')
# Out:
#            track_name artist(s)_name  artist_count  released_year  \
# 372   About Damn Time          Lizzo             1           2022
# 764   About Damn Time          Lizzo             1           2022
# 178              SNAP      Rosa Linn             1           2022
# 873              SNAP      Rosa Linn             1           2022
# 512    Take My Breath     The Weeknd             1           2021
# 616    Take My Breath     The Weeknd             1           2021
# 345  SPIT IN MY FACE!       ThxSoMch             1           2022
# 482  SPIT IN MY FACE!       ThxSoMch             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 372               7            15                  2332                  2
# 764               4            14                  9021                  0
# 178               3            19                  3202                 18
# ...

# %% [raw]
# Como se vio en estas dos de procedemos de ver cuáles datos son repetidos sacamos la conclucion de que donde mas se repiten en con las valores track_name y artist(s)_name

# %%
#Pero para saber cuantos canciones y artistas se repiten:
print(len(datos_csv_url))
datos_csv_url.groupby(by = ['track_name','artist(s)_name']).size().sort_values(ascending =False)
# Out:
# 952
# track_name             artist(s)_name
# About Damn Time        Lizzo                2
# SNAP                   Rosa Linn            2
# Take My Breath         The Weeknd           2
# SPIT IN MY FACE!       ThxSoMch             2
# 'Till I Collapse       Eminem, Nate Dogg    1
#                                            ..
# Heart To Heart         Mac DeMarco          1
# Heartless              Kanye West           1
# Heat Waves             Glass Animals        1
# Heather                Conan Gray           1
# ýýýýýýýýýýýýýýýýýýýýý  Fujii Kaze           1
# Length: 948, dtype: int64

# %% [raw]
# Como se puede ver solamente tenemos un dato repetido de este dataset que es "About Damn Time" pero este es solamente de de track_name con streams, pero con track_name con artist(s)_name hay varios repedidos, por lo tanto esos son los que se tiene que eliminar.

# %%
#Si queremos eliminar los duplicados, aplicamos la función drop_duplicates:
datos_csv_url_clean = datos_csv_url
datos_csv_url_clean.drop_duplicates(subset=['track_name','artist(s)_name'], keep='first', inplace=True)
print(len(datos_csv_url_clean))
datos_csv_url_clean
# Out:
# 948
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
#Verificamos que ya no estén repetidos:
datos_csv_url_clean[datos_csv_url_clean['track_name'] == 'About Damn Time'].sort_values('artist(s)_name')

#como anterior mente la canción About Damn Time tenia repetidos la verificaremos.
# Out:
#           track_name artist(s)_name  artist_count  released_year  \
# 372  About Damn Time          Lizzo             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 372               7            15                  2332                  2
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 372  723894473                   0  ...  109  A#  Minor             84
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 372         72       74             10                   0          34
#
#      speechiness_%
# 372              7
#
# [1 rows x 24 columns]

# %%
datos_csv_url_clean[datos_csv_url_clean['track_name'] == 'SPIT IN MY FACE!'].sort_values('artist(s)_name')
# Out:
#            track_name artist(s)_name  artist_count  released_year  \
# 345  SPIT IN MY FACE!       ThxSoMch             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 345              10            31                   629                 14
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 345  303216294                  32  ...   94  G#  Major             73
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 345         65       79              5                   2          11
#
#      speechiness_%
# 345              6
#
# [1 rows x 24 columns]

# %% [raw]
# Como se puede apreciar no hay datos repetidos.

# %% [markdown]
# 8. Encuentre en su dataset una característica categórica (no numérica) con pocos valores u opciones diferentes y conviertala en un dato numérico con la función cat.codes. Recuerde que el resultado se almacene en una nueva columna.

# %%
#Primero debemos cambiar el tipo de dato a un tipo categórico para que la función logre entender la transformación
datos_csv_url_clean['artist(s)_name'] = datos_csv_url_clean['artist(s)_name'].astype('category')
datos_csv_url_clean.dtypes
# Out:
# track_name                object
# artist(s)_name          category
# artist_count               int64
# released_year              int64
# released_month             int64
# released_day               int64
# in_spotify_playlists       int64
# in_spotify_charts          int64
# streams                    int64
# in_apple_playlists         int64
# in_apple_charts            int64
# in_deezer_playlists       object
# in_deezer_charts           int64
# in_shazam_charts          object
# bpm                        int64
# key                       object
# mode                      object
# danceability_%             int64
# valence_%                  int64
# energy_%                   int64
# acousticness_%             int64
# instrumentalness_%         int64
# liveness_%                 int64
# speechiness_%              int64
# dtype: object

# %%
datos_csv_url_clean['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                             34
# The Weeknd                               21
# SZA                                      19
# Bad Bunny                                19
# Harry Styles                             17
#                                          ..
# KALUSH                                    1
# Justin Quiles, Lenny Tavï¿½ï¿½rez, BL     1
# Justin Bieber, The Kid Laroi              1
# Justin Bieber, Don Toliver                1
# teto                                      1
# Name: count, Length: 644, dtype: int64

# %%
#Lo siguiente es agregar una nueva columna con los datos categorizados gracias a la función cat.codes de pandas
datos_csv_url_clean['Club_Art'] = datos_csv_url_clean['artist(s)_name'].cat.codes
datos_csv_url_clean.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 948                  0   91473363                  61  ...    A  Major
# ...

# %%
#Comprobamos que se haya hecho la cotegorización:
datos_csv_url_clean[datos_csv_url_clean['Club_Art'] == 1]
# Out:
#                 track_name    artist(s)_name  artist_count  released_year  \
# 582  thought i was playing  21 Savage, Gunna             2           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 582               1             7                   807                  0
#
#       streams  in_apple_playlists  ...  key   mode  danceability_% valence_%  \
# 582  60680939                   3  ...   C#  Major              68        29
#
#      energy_% acousticness_% instrumentalness_%  liveness_%  speechiness_%  \
# 582        73              0                  0           7              7
#
#      Club_Art
# 582         1
#
# [1 rows x 25 columns]

# %% [markdown]
# 9. Seleccione una característica numérica de su dataset y aplíquele una transformación, puede ser multiplicando, sumando, restanto, etc. No olvide ubicar el resultado en una nueva columna.

# %% [raw]
# Utilizaremos la categoría de 'streamer' para calcular el número total de oyentes que han escuchado las canciones de ese artista

# %%
oyentes_por_artista = datos_csv_url_clean.groupby('artist(s)_name', observed=False)['streams'].sum()
oyentes_por_artista
# Out:
# artist(s)_name
# (G)I-DLE                                          266983330
# 21 Savage, Gunna                                   60680939
# 24kgoldn, Iann Dior                              1699402402
# 50 Cent                                          1202722675
# A$AP Rocky, Metro Boomin, Roisee                   94186466
#                                                     ...
# j-hope                                            155795783
# j-hope, J. Cole                                   116599790
# sped up 8282                                      103762518
# sped up nightcore, ARIZONATEARS, Lil Uzi Vert     207033255
# teto                                              139193812
# Name: streams, Length: 644, dtype: int64

# %%
datos_csv_url_clean['listened'] = datos_csv_url_clean.groupby('artist(s)_name', observed=False)['streams'].transform('sum')
datos_csv_url_clean
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
datos_csv_url_clean['test'] = datos_csv_url_clean['streams']*2
datos_csv_url_clean.head()
#Existen muchas otras operaciones que iremos viendo más adelante
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  danceability_%  \
# ...

# %%
#Si queremos agregar una lógica de cuales jugadores son buenos y cuales son malos
datos_csv_url_clean['test2'] = datos_csv_url_clean['streams'] > 320336326
#datos_csv_url_clean.tail()
datos_csv_url_clean.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  valence_% energy_%  \
# ...

# %% [markdown]
# 10. Utilice los operadores relacionales para transformar una característica numérica en un dato categórico.

# %%
# Definir la función de clasificación
def clasificacion(x):
    if x['streams'] > 320336326:
        return 'Escuchado'
    elif 32033632 < x['streams'] < 320336326:
        return 'Medio'
    else:
        return 'Sordo'

# Aplicar la función a cada fila del DataFrame
datos_csv_url_clean['Escuchados_world'] = datos_csv_url_clean.apply(clasificacion, axis=1)

# Mostrar los primeros registros del DataFrame con la nueva columna
datos_csv_url_clean.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  energy_%  \
# ...

# %% [raw]
# 11. Guarde el resultado final de su dataset.

# %%
#Para escribir datos o guardar nuestro dataframe transformado basta con usar: 
# df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')
datos_csv_url_clean.to_csv('Datos_procesados_Spotify.csv', encoding='utf-8-sig')

# %% [raw]
# 12. Utilice las funciones gráficas vistas en clase para graficar los datos que usted crea conveniente. Recuerde que solo puede graficar las características numéricas. Al menos debe obtener 3 tipos diferentes de gráficas.

# %%
import matplotlib.pyplot as plt

# Contar la frecuencia de cada categoría en la columna 'Escuchados_world'
frecuencia_categorias = datos_csv_url_clean['Escuchados_world'].value_counts()

# Crear la gráfica de barras
plt.bar(frecuencia_categorias.index, frecuencia_categorias.values)

# Agregar etiquetas y título
plt.xlabel('Categoría de audición')
plt.ylabel('Cantidad')
plt.title('Frecuencia de Categorías en Escuchados_world')

# Mostrar la gráfica
plt.show()

# %%
import matplotlib.pyplot as plt

# Contar la frecuencia de cada categoría en la columna 'Escuchados_world'
frecuencia_categorias = datos_csv_url_clean['Escuchados_world'].value_counts()

# Crear la gráfica de pastel
plt.pie(frecuencia_categorias.values, labels=frecuencia_categorias.index, autopct='%1.1f%%')

# Agregar título
plt.title('Frecuencia de Categorías en Escuchados_world')

# Mostrar la gráfica
plt.show()

# %%
import matplotlib.pyplot as plt

# Contar la frecuencia de cada categoría en la columna 'Escuchados_world'
frecuencia_categorias = datos_csv_url_clean['Escuchados_world'].value_counts()

# Ordenar los valores por categoría
frecuencia_categorias = frecuencia_categorias.sort_index()

# Crear la gráfica de líneas
plt.plot(frecuencia_categorias.index, frecuencia_categorias.values, marker='o')

# Agregar etiquetas y título
plt.xlabel('Categoría de audición')
plt.ylabel('Cantidad')
plt.title('Frecuencia de Categorías en Escuchados_world')

# Mostrar la gráfica
plt.show()

# %%
graph = datos_csv_url_clean.groupby(by = ['Escuchados_world']).size()
graph
# Out:
# Escuchados_world
# Escuchado    437
# Medio        498
# Sordo         13
# dtype: int64

# %%
graph = datos_csv_url_clean.groupby(by = ['Escuchados_world']).plot()
graph
# Out:
# Escuchados_world
# Escuchado    Axes(0.125,0.11;0.775x0.77)
# Medio        Axes(0.125,0.11;0.775x0.77)
# Sordo        Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [raw]
# Posdata: No puede usar bien la funcion de graph en notebook, utilize el mismo codigo que uso en Ingenieria_de_Datos.ipynb pero no
# me funciono.
